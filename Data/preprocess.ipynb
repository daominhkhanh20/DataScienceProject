# %%
import pandas as pd

# %%
dataset = pd.read_csv("AggregateData.csv")

# %%
dataset.shape
# Out:
# (70889, 17)

# %%
dataset.head()
# Out:
#                                          description    origin      status  \
# 0  🔹 HÀNG MỚI VỀ\n🔹 BMW 520i \n🔹 MODEL 2016\n🔹 Od...       Đức  Đã sử dụng
# 1  Bán nissan - Gran Livina nhập khẩu số tự động ...  Nhật Bản  Đã sử dụng
# 2  Auto88 về Mercedes C200 sx 2017 đky 2/2018 chạ...  Việt Nam  Đã sử dụng
# 3  xe còn đẹp gia đình đang xử dụng. Cần bán xe đ...  Nhật Bản  Đã sử dụng
# 4  Xe gia đình đi, còn khá mới vì do công việc nê...  Việt Nam  Đã sử dụng
#
#    car_mileage car_color  car_seats     gear  car_year     car_price  \
# 0      50000.0       Đen        4.0  Tự động    2015.0  1.170000e+09
# 1      12000.0       Xám        3.0  Tự động    2009.0  2.700000e+02
# 2      30000.0       Xám        2.0  Tự động    2018.0  1.090000e+09
# 3        120.0     Trắng        2.0  Tự động    2017.0  4.900000e+08
# 4      53000.0       Đen        2.0  Tự động    2016.0  4.000000e+08
#
#            style      createdAt         model  fuel     brand_name  \
# 0          Sedan   2 phút trước      5 Series  Xăng            BMW
# 1  Minivan (MPV)   6 phút trước  Grand livina  Xăng         Nissan
# 2          Sedan   7 phút trước       C Class  Xăng  Mercedes Benz
# 3      Hatchback   9 phút trước          CX 3  Xăng          Mazda
# 4          Sedan  10 phút trước         Cruze  Xăng      Chevrolet
#
#       region_name                                          url_image website
# 0          Hà Nội  https://cdn.chotot.com/namB6E0XkDPkf9h8KoahoRB...  chotot
# 1          Hà Nội  https://cdn.chotot.com/50R_cYWFPAz0wHZqPAGaFr-...  chotot
# 2          Hà Nội  https://cdn.chotot.com/bhfeL3dPtccDnzlKzeAZ88X...  chotot
# 3        An Giang  https://cdn.chotot.com/bZA5uIvzseB-MBKCPcDKe4K...  chotot
# 4  Tp Hồ Chí Minh  https://cdn.chotot.com/c7q5pfENmvTLnzxYQ7MA70P...  chotot

# %% [markdown]
# # Remove nan in brand name

# %%
dataset = dataset.sort_values(by=["brand_name"], axis = 0).reset_index()

# %%
dataset = dataset.iloc[:68843]

# %%
dataset[dataset["brand_name"].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, description, origin, status, car_mileage, car_color, car_seats, gear, car_year, car_price, style, createdAt, model, fuel, brand_name, region_name, url_image, website]
# Index: []

# %% [markdown]
# # Transform date
#     * Only select month

# %%
dataset
# Out:
#        index                                        description     origin  \
# 0      10690  Xe không đi cần thanh lý Xe đã qua sử dụng, đi...  Nước khác
# 1      29880    Xe ko lỗi nhỏ nguyên zin\nĐồ đạc thay gần 100tr  Nước khác
# 2      19487  ko có nhu cầu sử dụng cần bán masda6 đời 2004 ...   Việt Nam
# 3       5239  Ai aia íbs idhsb hsgsbs hsvd hsvd ndhs jdhd hs...   Việt Nam
# 4      27699  xe đẹp từ trong ra ngoài năm sx 2013 , xe v...        NaN
# ...      ...                                                ...        ...
# 68838  47499  ✓ Miễn phí thuế trước bạ ✓ Vay miễn lãi 0% ✓ G...   Việt Nam
# 68839  47201  VINFAST FADIL Ông vua phân khúc hạng A: 1.Fadi...   Việt Nam
# 68840  46683  GIÁ SIÊU HOT TẶNG QUÀ NHÂN ĐÔI  Báo giá ngay...   Việt Nam
# 68841  46620  Lux A giảm 10% giá xe, tặng 100% thuế trước bạ...   Việt Nam
# 68842  46595  Vinfast Fadil bản cao cấp ** CTKM trả góp tối ...   Việt Nam
#
#            status  car_mileage car_color  car_seats     gear  car_year  \
# 0      Đã sử dụng     120000.0       Đen        6.0  Tự động    2007.0
# 1      Đã sử dụng     110000.0       Bạc        3.0  Tự động    2008.0
# 2      Đã sử dụng        220.0       Đen        4.0   Số sàn    2004.0
# 3      Đã sử dụng     120000.0     Trắng        NaN  Tự động    2017.0
# 4      Đã sử dụng     100000.0       NaN        NaN   Số sàn    2013.0
# ...           ...          ...       ...        ...      ...       ...
# 68838         Mới          0.0       Đen        7.0  Tự động    2021.0
# 68839         Mới          0.0       Xám        5.0  Tự động    2021.0
# 68840         Mới          0.0        Đỏ        5.0  Tự động    2021.0
# 68841         Mới          0.0       Nâu        5.0  Tự động    2021.0
# 68842         Mới          0.0       Xám        5.0  Tự động    2021.0
#
#           car_price             style      createdAt       model  fuel  \
# 0      4.500000e+08  SUV / Cross over   1 tuần trước         MDX  Xăng
# 1      4.600000e+08  SUV / Cross over  2 tháng trước         MDX  Xăng
# 2      2.200000e+08    Kiểu dáng khác   3 tuần trước   Dòng khác  Xăng
# 3      5.555556e+07               NaN   2 ngày trước          CL   NaN
# 4      3.000000e+08               NaN  2 tháng trước   Dòng khác   NaN
# ...             ...               ...            ...         ...   ...
# 68838  1.298000e+09  SUV / Cross over      3/12/2021  Lux Sa 2.0  Xăng
# 68839  4.130000e+08         Hatchback      3/12/2021       Fadil  Xăng
# 68840  9.480000e+08             Sedan      3/12/2021         Lux  Xăng
# 68841  9.480000e+08             Sedan      3/12/2021         Lux  Xăng
# 68842  4.490000e+08         Hatchback      3/12/2021       Fadil  Xăng
#
#       brand_name     region_name  \
# 0          Acura         Gia Lai
# 1          Acura          Hà Nội
# 2          Acura         Phú Yên
# 3          Acura      Quảng Ninh
# 4          Acura       Vĩnh Long
# ...          ...             ...
# 68838    VinFast          Hà Nội
# 68839    VinFast          Hà Nội
# 68840    VinFast  Tp Hồ Chí Minh
# 68841    VinFast         Phú Thọ
# 68842    VinFast          Hà Nam
#
#                                                url_image  website
# 0      https://cdn.chotot.com/mXCnbhOgz8MATrziNWpTb7d...   chotot
# 1      https://cdn.chotot.com/x4XNIm8FY0_eHbx-YEf4SC7...   chotot
# 2      https://cdn.chotot.com/N38b2el7cufbYZD_afLXmup...   chotot
# 3      https://cdn.chotot.com/jPaPPwhaq6Qc7y0wkxDLoy4...   chotot
# 4      https://cdn.chotot.com/hB3LXQfsrZ4Yj7A1yJzv5uC...   chotot
# ...                                                  ...      ...
# 68838  https://bonbanh.com/uploads/users/519120/car/3...  bonbanh
# 68839  https://bonbanh.com/uploads/users/518557/car/3...  bonbanh
# 68840  https://bonbanh.com/uploads/users/551096/car/3...  bonbanh
# 68841  https://bonbanh.com/uploads/users/537019/car/3...  bonbanh
# 68842  https://bonbanh.com/uploads/users/509606/car/3...  bonbanh
#
# [68843 rows x 18 columns]

# %%
def transform_data(dataset):
    datetime = dataset["createdAt"]
    year = []
    month = []
    for x in datetime:
        if x[-2:] == "ớc":
            if "tháng" in x:
                time_duration = int(x.split(" ")[0])
                create_month = 11 - time_duration
                if create_month < 1:
                    create_month += 12
                    create_year = 2020
                else:
                    create_year = 2021
            else:
                create_month = 11
                create_year = 2021
            year.append(create_year)
            month.append(create_month)
        elif x == "hôm qua":
            month.append(11)
            year.append(2021)
        else:
            print(x.split('/'))
            month_, year_ = x.split("/")[1:]
            month.append(int(month_))
            year.append(int(year_))
    return month, year

# %%
month, year = transform_data(dataset)
# Out:
# ['28', '11', '2021']
# ['1', '04', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['3', '12', '2021']
# ['26', '10', '2021']
# ['5', '12', '2021']
# ['15', '11', '2021']
# ['25', '11', '2021']
# ['6', '12', '2021']
# ['30', '11', '2021']
# ['10', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['14', '10', '2021']
# ['29', '11', '2021']
# ['27', '11', '2021']
# ['6', '12', '2021']
# ['9', '09', '2021']
# ['10', '11', '2021']
# ['28', '10', '2021']
# ['7', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['10', '10', '2021']
# ['6', '12', '2021']
# ['29', '10', '2021']
# ['3', '12', '2021']
# ['6', '12', '2021']
# ['12', '08', '2021']
# ['10', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['11', '08', '2021']
# ['6', '12', '2021']
# ['7', '11', '2021']
# ['8', '10', '2021']
# ['28', '04', '2021']
# ['6', '12', '2021']
# ['10', '11', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['29', '10', '2021']
# ['28', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['8', '10', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['6', '12', '2021']
# ['18', '08', '2021']
# ['6', '12', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['19', '12', '2020']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['1', '12', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['15', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['15', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['7', '10', '2021']
# ['2', '12', '2021']
# ['6', '12', '2021']
# ['2', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['2', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['3', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['10', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['7', '10', '2021']
# ['6', '12', '2021']
# ['29', '10', '2021']
# ['14', '11', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['18', '07', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['23', '10', '2021']
# ['19', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['17', '10', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '11', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['22', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['21', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['21', '07', '2021']
# ['5', '12', '2021']
# ['23', '10', '2021']
# ['23', '10', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['22', '10', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['6', '11', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['13', '10', '2021']
# ['26', '10', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['3', '12', '2021']
# ['9', '08', '2021']
# ['3', '12', '2021']
# ['12', '10', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['11', '10', '2021']
# ['5', '12', '2021']
# ['12', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['3', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['13', '10', '2021']
# ['6', '11', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['25', '10', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['14', '10', '2021']
# ['5', '08', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['13', '11', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['3', '12', '2021']
# ['30', '11', '2021']
# ['4', '12', '2021']
# ['27', '11', '2021']
# ['21', '11', '2021']
# ['27', '11', '2021']
# ['20', '11', '2021']
# ['20', '11', '2021']
# ['16', '09', '2021']
# ['20', '11', '2021']
# ['26', '11', '2021']
# ['26', '11', '2021']
# ['27', '11', '2021']
# ['27', '11', '2021']
# ['16', '11', '2021']
# ['27', '11', '2021']
# ['2', '11', '2021']
# ['27', '11', '2021']
# ['22', '11', '2021']
# ['24', '11', '2021']
# ['22', '11', '2021']
# ['22', '11', '2021']
# ['23', '11', '2021']
# ['23', '11', '2021']
# ['23', '11', '2021']
# ['22', '09', '2021']
# ['23', '11', '2021']
# ['4', '11', '2021']
# ['24', '11', '2021']
# ['22', '11', '2021']
# ['27', '09', '2021']
# ['25', '11', '2021']
# ['25', '09', '2021']
# ['8', '11', '2021']
# ['25', '11', '2021']
# ['22', '11', '2021']
# ['22', '11', '2021']
# ['24', '11', '2021']
# ['19', '11', '2021']
# ['9', '09', '2021']
# ['17', '11', '2021']
# ['18', '11', '2021']
# ['10', '09', '2021']
# ['6', '12', '2021']
# ['5', '11', '2021']
# ['13', '09', '2021']
# ['18', '11', '2021']
# ['10', '09', '2021']
# ['29', '11', '2021']
# ['21', '08', '2021']
# ['29', '11', '2021']
# ['10', '09', '2021']
# ['29', '11', '2021']
# ['17', '11', '2021']
# ['30', '11', '2021']
# ['6', '12', '2021']
# ['20', '11', '2020']
# ['19', '11', '2021']
# ['12', '09', '2021']
# ['6', '12', '2021']
# ['30', '11', '2021']
# ['24', '06', '2021']
# ['23', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['21', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['26', '10', '2021']
# ['4', '12', '2021']
# ['24', '06', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['5', '11', '2021']
# ['21', '11', '2021']
# ['21', '11', '2021']
# ['4', '12', '2021']
# ['30', '06', '2021']
# ['4', '12', '2021']
# ['23', '11', '2021']
# ['22', '06', '2021']
# ['4', '12', '2021']
# ['17', '11', '2021']
# ['22', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['19', '06', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['21', '06', '2021']
# ['21', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['28', '07', '2021']
# ['21', '10', '2021']
# ['4', '12', '2021']
# ['25', '09', '2021']
# ['22', '11', '2021']
# ['3', '07', '2021']
# ['4', '12', '2021']
# ['21', '07', '2021']
# ['4', '12', '2021']
# ['27', '10', '2021']
# ['23', '07', '2021']
# ['18', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['6', '07', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['19', '11', '2021']
# ['22', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['23', '10', '2021']
# ['19', '11', '2021']
# ['22', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['24', '10', '2021']
# ['4', '12', '2021']
# ['24', '10', '2021']
# ['19', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['3', '07', '2021']
# ['4', '12', '2021']
# ['18', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['22', '10', '2021']
# ['22', '10', '2021']
# ['22', '10', '2021']
# ['18', '11', '2021']
# ['4', '12', '2021']
# ['25', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['20', '11', '2021']
# ['4', '12', '2021']
# ['18', '11', '2021']
# ['3', '07', '2021']
# ['18', '11', '2021']
# ['18', '11', '2021']
# ['3', '07', '2021']
# ['22', '10', '2021']
# ['5', '07', '2021']
# ['22', '10', '2021']
# ['5', '07', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['18', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['6', '07', '2021']
# ['20', '11', '2021']
# ['6', '07', '2021']
# ['18', '11', '2021']
# ['6', '07', '2021']
# ['5', '07', '2021']
# ['20', '11', '2021']
# ['6', '07', '2021']
# ['4', '12', '2021']
# ['5', '07', '2021']
# ['22', '10', '2021']
# ['5', '07', '2021']
# ['4', '12', '2021']
# ['30', '11', '2021']
# ['16', '03', '2021']
# ['28', '11', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['29', '11', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['30', '10', '2021']
# ['29', '11', '2021']
# ['2', '11', '2021']
# ['2', '12', '2021']
# ['29', '10', '2021']
# ['29', '10', '2021']
# ['2', '12', '2021']
# ['27', '11', '2021']
# ['29', '03', '2021']
# ['27', '11', '2021']
# ['26', '03', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['27', '11', '2021']
# ['27', '11', '2021']
# ['2', '11', '2021']
# ['2', '11', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['28', '11', '2021']
# ['28', '11', '2021']
# ['10', '03', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['24', '01', '2021']
# ['1', '11', '2021']
# ['1', '12', '2021']
# ['2', '11', '2021']
# ['1', '12', '2021']
# ['30', '11', '2021']
# ['30', '11', '2021']
# ['29', '11', '2021']
# ['30', '11', '2021']
# ['30', '11', '2021']
# ['30', '11', '2021']
# ['30', '11', '2021']
# ['30', '11', '2021']
# ['30', '11', '2021']
# ['29', '11', '2021']
# ['1', '12', '2021']
# ['1', '12', '2021']
# ['29', '11', '2021']
# ['2', '12', '2021']
# ['31', '10', '2021']
# ['29', '11', '2021']
# ['29', '11', '2021']
# ['27', '02', '2021']
# ['1', '12', '2021']
# ['1', '12', '2021']
# ['31', '10', '2021']
# ['29', '11', '2021']
# ['29', '11', '2021']
# ['1', '12', '2021']
# ['1', '11', '2021']
# ['1', '12', '2021']
# ['1', '12', '2021']
# ['1', '12', '2021']
# ['23', '11', '2021']
# ['29', '10', '2021']
# ['26', '05', '2021']
# ['3', '12', '2021']
# ['7', '08', '2021']
# ['26', '05', '2021']
# ['25', '11', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['25', '11', '2021']
# ['26', '05', '2021']
# ['25', '11', '2021']
# ['25', '11', '2021']
# ['3', '11', '2021']
# ['23', '05', '2021']
# ['23', '05', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['27', '10', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['26', '05', '2021']
# ['30', '11', '2021']
# ['26', '05', '2021']
# ['4', '12', '2021']
# ['16', '06', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['23', '11', '2021']
# ['26', '10', '2021']
# ['4', '12', '2021']
# ['27', '10', '2021']
# ['23', '11', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['26', '05', '2021']
# ['26', '05', '2021']
# ['26', '05', '2021']
# ['25', '11', '2021']
# ['3', '12', '2021']
# ['3', '11', '2021']
# ['3', '12', '2021']
# ['28', '04', '2021']
# ['3', '12', '2021']
# ['28', '10', '2021']
# ['26', '11', '2021']
# ['8', '05', '2020']
# ['26', '11', '2021']
# ['3', '12', '2021']
# ['16', '04', '2021']
# ['3', '12', '2021']
# ['27', '11', '2021']
# ['3', '12', '2021']
# ['29', '10', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['27', '11', '2021']
# ['29', '11', '2021']
# ['2', '12', '2021']
# ['3', '12', '2021']
# ['26', '04', '2021']
# ['28', '10', '2021']
# ['21', '06', '2021']
# ['3', '12', '2021']
# ['28', '10', '2021']
# ['28', '10', '2021']
# ['28', '10', '2021']
# ['3', '12', '2021']
# ['28', '10', '2021']
# ['3', '11', '2021']
# ['26', '11', '2021']
# ['26', '11', '2021']
# ['3', '12', '2021']
# ['26', '11', '2021']
# ['28', '10', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['26', '11', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['20', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['20', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['3', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['29', '09', '2021']
# ['24', '08', '2021']
# ['6', '12', '2021']
# ['30', '09', '2021']
# ['22', '08', '2021']
# ['30', '09', '2021']
# ['6', '12', '2021']
# ['4', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['4', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['17', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '10', '2021']
# ['4', '09', '2021']
# ['5', '09', '2021']
# ['16', '09', '2021']
# ['3', '09', '2021']
# ['11', '09', '2021']
# ['10', '09', '2021']
# ['9', '09', '2021']
# ['9', '09', '2021']
# ['14', '09', '2021']
# ['8', '09', '2021']
# ['8', '09', '2021']
# ['6', '12', '2021']
# ['21', '09', '2021']
# ['28', '09', '2021']
# ['28', '09', '2021']
# ['26', '08', '2021']
# ['27', '09', '2021']
# ['29', '09', '2021']
# ['28', '09', '2021']
# ['25', '08', '2021']
# ['30', '08', '2021']
# ['23', '09', '2021']
# ['22', '09', '2021']
# ['22', '09', '2021']
# ['22', '09', '2021']
# ['31', '08', '2021']
# ['26', '09', '2021']
# ['25', '09', '2021']
# ['24', '09', '2021']
# ['30', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['7', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['1', '08', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['18', '10', '2021']
# ['18', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['17', '10', '2021']
# ['17', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['18', '10', '2021']
# ['19', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['18', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['18', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['17', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['17', '11', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['16', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['14', '10', '2021']
# ['19', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['21', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['21', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['28', '07', '2021']
# ['21', '10', '2021']
# ['5', '12', '2021']
# ['21', '10', '2021']
# ['5', '12', '2021']
# ['21', '10', '2021']
# ['19', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['19', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['20', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['12', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['9', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['9', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['8', '10', '2021']
# ['12', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['10', '10', '2021']
# ['10', '10', '2021']
# ['10', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['10', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['13', '08', '2021']
# ['6', '12', '2021']
# ['7', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['7', '10', '2021']
# ['7', '10', '2021']
# ['8', '10', '2021']
# ['6', '12', '2021']
# ['8', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['8', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['12', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['14', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['13', '10', '2021']
# ['14', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['12', '10', '2021']
# ['9', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['11', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['7', '08', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['8', '08', '2021']
# ['12', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['31', '10', '2021']
# ['11', '09', '2021']
# ['12', '11', '2021']
# ['19', '11', '2021']
# ['13', '11', '2021']
# ['13', '11', '2021']
# ['13', '11', '2021']
# ['7', '11', '2021']
# ['9', '11', '2021']
# ['13', '11', '2021']
# ['17', '11', '2021']
# ['13', '11', '2021']
# ['13', '11', '2021']
# ['13', '11', '2021']
# ['13', '11', '2021']
# ['12', '11', '2021']
# ['16', '11', '2021']
# ['10', '11', '2021']
# ['9', '11', '2021']
# ['8', '11', '2021']
# ['7', '11', '2021']
# ['10', '11', '2021']
# ['11', '11', '2021']
# ['12', '11', '2021']
# ['14', '11', '2021']
# ['16', '11', '2021']
# ['16', '11', '2021']
# ['9', '11', '2021']
# ['9', '11', '2021']
# ['9', '11', '2021']
# ['9', '11', '2021']
# ['5', '11', '2021']
# ['16', '11', '2021']
# ['5', '11', '2021']
# ['14', '11', '2021']
# ['16', '11', '2021']
# ['25', '11', '2021']
# ['9', '11', '2021']
# ['6', '11', '2021']
# ['9', '11', '2021']
# ['9', '11', '2021']
# ['5', '11', '2021']
# ['15', '11', '2021']
# ['4', '12', '2021']
# ['28', '10', '2021']
# ['23', '11', '2021']
# ['14', '11', '2021']
# ['13', '11', '2021']
# ['4', '12', '2021']
# ['1', '12', '2021']
# ['1', '12', '2021']
# ['19', '11', '2021']
# ['24', '08', '2021']
# ['10', '11', '2021']
# ['18', '08', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['26', '10', '2021']
# ['13', '11', '2021']
# ['6', '12', '2021']
# ['13', '11', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['13', '11', '2021']
# ['2', '11', '2021']
# ['29', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['25', '10', '2021']
# ['13', '07', '2021']
# ['13', '07', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['28', '11', '2021']
# ['6', '12', '2021']
# ['23', '10', '2021']
# ['1', '12', '2021']
# ['17', '11', '2020']
# ['30', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['1', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['31', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['30', '10', '2021']
# ['6', '12', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['19', '08', '2021']
# ['19', '04', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['30', '11', '2021']
# ['5', '11', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['26', '05', '2021']
# ['6', '11', '2021']
# ['3', '12', '2021']
# ['6', '12', '2021']
# ['3', '12', '2021']
# ['1', '11', '2021']
# ['3', '12', '2021']
# ['6', '12', '2021']
# ['23', '10', '2021']
# ['23', '10', '2021']
# ['4', '12', '2021']
# ['9', '11', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['17', '11', '2021']
# ['5', '12', '2021']
# ['14', '10', '2021']
# ['5', '12', '2021']
# ['22', '11', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['22', '11', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['22', '11', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['19', '11', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['16', '10', '2021']
# ['25', '11', '2021']
# ['28', '11', '2021']
# ['22', '10', '2021']
# ['6', '12', '2021']
# ['5', '11', '2021']
# ['21', '10', '2021']
# ['21', '10', '2021']
# ['27', '11', '2021']
# ['26', '11', '2021']
# ['29', '07', '2021']
# ['5', '12', '2021']
# ['1', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['20', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['20', '11', '2021']
# ['27', '11', '2021']
# ['16', '11', '2021']
# ['3', '11', '2021']
# ['30', '09', '2021']
# ['3', '11', '2021']
# ['29', '11', '2021']
# ['10', '01', '2021']
# ['7', '09', '2021']
# ['4', '11', '2021']
# ['1', '11', '2021']
# ['30', '11', '2021']
# ['22', '09', '2021']
# ['6', '12', '2021']
# ['31', '10', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['12', '11', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['9', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['14', '09', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['31', '10', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['6', '12', '2021']
# ['18', '04', '2021']
# ['14', '11', '2021']
# ['3', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['5', '10', '2021']
# ['6', '12', '2021']
# ['21', '10', '2021']
# ['30', '10', '2021']
# ['17', '11', '2021']
# ['21', '08', '2021']
# ['1', '11', '2021']
# ['5', '10', '2021']
# ['23', '11', '2021']
# ['24', '11', '2021']
# ['30', '11', '2021']
# ['30', '08', '2021']
# ['23', '11', '2021']
# ['30', '09', '2021']
# ['30', '10', '2021']
# ['25', '10', '2021']
# ['12', '10', '2021']
# ['5', '12', '2021']
# ['9', '08', '2021']
# ['23', '09', '2021']
# ['12', '10', '2021']
# ['12', '10', '2021']
# ['5', '12', '2021']
# ['12', '10', '2021']
# ['3', '07', '2021']
# ['12', '10', '2021']
# ['5', '12', '2021']
# ['1', '12', '2021']
# ['26', '11', '2021']
# ['26', '11', '2021']
# ['7', '11', '2021']
# ['25', '10', '2021']
# ['26', '11', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['7', '09', '2021']
# ['12', '10', '2021']
# ['26', '11', '2021']
# ['22', '09', '2021']
# ['2', '11', '2021']
# ['26', '11', '2021']
# ['5', '12', '2021']
# ['7', '08', '2021']
# ['4', '12', '2021']
# ['9', '08', '2021']
# ['6', '12', '2021']
# ['11', '10', '2021']
# ['6', '12', '2021']
# ['9', '08', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['11', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['11', '10', '2021']
# ['6', '12', '2021']
# ['11', '11', '2021']
# ['11', '10', '2021']
# ['4', '12', '2021']
# ['5', '09', '2021']
# ['16', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['22', '09', '2021']
# ['1', '12', '2021']
# ['5', '12', '2021']
# ['8', '09', '2021']
# ['1', '07', '2021']
# ['17', '11', '2021']
# ['8', '08', '2021']
# ['1', '11', '2021']
# ['2', '07', '2021']
# ['9', '08', '2021']
# ['1', '12', '2021']
# ['1', '12', '2021']
# ['12', '10', '2021']
# ['18', '11', '2021']
# ['12', '10', '2021']
# ['23', '01', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['3', '07', '2019']
# ['5', '12', '2021']
# ['26', '11', '2021']
# ['12', '10', '2021']
# ['5', '11', '2021']
# ['6', '11', '2021']
# ['17', '11', '2021']
# ['25', '10', '2021']
# ['5', '11', '2021']
# ['27', '11', '2021']
# ['9', '11', '2021']
# ['14', '10', '2021']
# ['11', '11', '2021']
# ['5', '08', '2021']
# ['13', '11', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['27', '11', '2021']
# ['5', '08', '2021']
# ['27', '11', '2021']
# ['9', '09', '2021']
# ['27', '11', '2021']
# ['5', '12', '2021']
# ['25', '10', '2021']
# ['5', '08', '2021']
# ['5', '11', '2021']
# ['27', '11', '2021']
# ['14', '10', '2021']
# ['5', '12', '2021']
# ['5', '08', '2021']
# ['1', '11', '2021']
# ['14', '10', '2021']
# ['5', '08', '2021']
# ['13', '10', '2021']
# ['5', '12', '2021']
# ['29', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['8', '11', '2021']
# ['5', '07', '2021']
# ['25', '10', '2021']
# ['25', '10', '2021']
# ['28', '11', '2021']
# ['25', '10', '2021']
# ['6', '08', '2021']
# ['5', '12', '2021']
# ['26', '11', '2021']
# ['13', '10', '2021']
# ['22', '09', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['26', '11', '2021']
# ['6', '08', '2021']
# ['4', '12', '2021']
# ['2', '07', '2021']
# ['12', '10', '2021']
# ['1', '11', '2021']
# ['26', '11', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '08', '2021']
# ['13', '10', '2021']
# ['5', '08', '2021']
# ['5', '12', '2021']
# ['1', '11', '2021']
# ['5', '08', '2021']
# ['27', '11', '2021']
# ['5', '08', '2021']
# ['26', '11', '2021']
# ['13', '10', '2021']
# ['13', '10', '2021']
# ['13', '10', '2021']
# ['25', '10', '2021']
# ['31', '08', '2021']
# ['5', '08', '2021']
# ['5', '08', '2021']
# ['3', '11', '2021']
# ['6', '12', '2021']
# ['25', '11', '2021']
# ['6', '12', '2021']
# ['12', '08', '2021']
# ['6', '12', '2021']
# ['28', '07', '2021']
# ['14', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['12', '08', '2021']
# ['10', '11', '2021']
# ['1', '12', '2021']
# ['5', '09', '2021']
# ['10', '11', '2021']
# ['27', '07', '2021']
# ['17', '11', '2021']
# ['12', '08', '2021']
# ['12', '08', '2021']
# ['9', '10', '2021']
# ['5', '11', '2021']
# ['9', '10', '2021']
# ['4', '12', '2021']
# ['30', '08', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['18', '06', '2021']
# ['25', '11', '2021']
# ['25', '11', '2021']
# ['9', '10', '2021']
# ['10', '11', '2021']
# ['13', '11', '2021']
# ['9', '10', '2021']
# ['25', '11', '2021']
# ['10', '11', '2021']
# ['6', '12', '2021']
# ['9', '10', '2021']
# ['6', '12', '2021']
# ['12', '08', '2021']
# ['11', '09', '2021']
# ['25', '11', '2021']
# ['4', '08', '2021']
# ['30', '08', '2021']
# ['3', '11', '2021']
# ['6', '12', '2021']
# ['9', '11', '2021']
# ['8', '10', '2021']
# ['6', '12', '2021']
# ['12', '08', '2021']
# ['16', '09', '2021']
# ['1', '12', '2021']
# ['10', '11', '2021']
# ['4', '08', '2021']
# ['7', '10', '2021']
# ['25', '11', '2021']
# ['24', '09', '2021']
# ['25', '11', '2021']
# ['13', '08', '2021']
# ['26', '10', '2021']
# ['13', '08', '2021']
# ['1', '12', '2021']
# ['14', '09', '2021']
# ['6', '12', '2021']
# ['26', '10', '2021']
# ['24', '09', '2021']
# ['8', '10', '2021']
# ['6', '12', '2021']
# ['6', '09', '2021']
# ['6', '12', '2021']
# ['26', '10', '2021']
# ['25', '11', '2021']
# ['9', '11', '2021']
# ['6', '12', '2021']
# ['17', '06', '2021']
# ['10', '11', '2021']
# ['13', '08', '2021']
# ['25', '11', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['3', '11', '2021']
# ['13', '08', '2021']
# ['14', '08', '2021']
# ['8', '11', '2021']
# ['9', '09', '2021']
# ['15', '11', '2021']
# ['24', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['10', '08', '2021']
# ['10', '08', '2021']
# ['26', '11', '2021']
# ['10', '08', '2021']
# ['25', '10', '2021']
# ['26', '11', '2021']
# ['30', '08', '2021']
# ['11', '10', '2021']
# ['6', '12', '2021']
# ['26', '11', '2021']
# ['19', '11', '2021']
# ['11', '10', '2021']
# ['10', '08', '2021']
# ['26', '10', '2021']
# ['4', '12', '2021']
# ['26', '10', '2021']
# ['10', '08', '2021']
# ['9', '08', '2021']
# ['6', '12', '2021']
# ['30', '08', '2021']
# ['7', '11', '2021']
# ['26', '11', '2021']
# ['6', '12', '2021']
# ['31', '08', '2021']
# ['4', '12', '2021']
# ['1', '12', '2021']
# ['10', '08', '2021']
# ['4', '09', '2021']
# ['5', '11', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['16', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['25', '11', '2021']
# ['11', '08', '2021']
# ['13', '11', '2021']
# ['3', '11', '2021']
# ['25', '11', '2021']
# ['6', '12', '2021']
# ['23', '09', '2021']
# ['26', '10', '2021']
# ['17', '11', '2021']
# ['15', '11', '2021']
# ['4', '12', '2021']
# ['6', '07', '2021']
# ['9', '10', '2021']
# ['25', '11', '2021']
# ['6', '12', '2021']
# ['8', '11', '2021']
# ['10', '11', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['11', '10', '2021']
# ['3', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['3', '11', '2021']
# ['10', '08', '2021']
# ['11', '10', '2021']
# ['4', '12', '2021']
# ['10', '10', '2021']
# ['7', '11', '2021']
# ['10', '10', '2021']
# ['10', '10', '2021']
# ['30', '08', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['30', '08', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['26', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['30', '11', '2021']
# ['29', '11', '2021']
# ['6', '11', '2021']
# ['4', '12', '2021']
# ['3', '09', '2021']
# ['8', '11', '2021']
# ['5', '12', '2021']
# ['20', '10', '2021']
# ['29', '11', '2021']
# ['12', '11', '2021']
# ['6', '11', '2021']
# ['29', '11', '2021']
# ['29', '11', '2021']
# ['5', '12', '2021']
# ['29', '07', '2021']
# ['29', '07', '2021']
# ['29', '07', '2021']
# ['5', '12', '2021']
# ['1', '11', '2021']
# ['4', '12', '2021']
# ['29', '11', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['20', '10', '2021']
# ['4', '12', '2021']
# ['29', '07', '2021']
# ['15', '11', '2021']
# ['5', '12', '2021']
# ['9', '11', '2021']
# ['9', '11', '2021']
# ['20', '10', '2021']
# ['29', '11', '2021']
# ['29', '11', '2021']
# ['18', '09', '2021']
# ['19', '09', '2021']
# ['20', '10', '2021']
# ['5', '12', '2021']
# ['19', '10', '2021']
# ['5', '12', '2021']
# ['12', '11', '2021']
# ['12', '11', '2021']
# ['29', '11', '2021']
# ['30', '07', '2021']
# ['20', '09', '2021']
# ['5', '12', '2021']
# ['19', '09', '2021']
# ['13', '09', '2021']
# ['5', '12', '2021']
# ['19', '10', '2021']
# ['23', '10', '2021']
# ['13', '09', '2021']
# ['15', '11', '2021']
# ['30', '07', '2021']
# ['5', '12', '2021']
# ['29', '11', '2021']
# ['19', '10', '2021']
# ['30', '07', '2021']
# ['29', '11', '2021']
# ['5', '12', '2021']
# ['23', '10', '2021']
# ['2', '11', '2021']
# ['5', '12', '2021']
# ['29', '11', '2021']
# ['29', '11', '2021']
# ['29', '11', '2021']
# ['29', '11', '2021']
# ['12', '11', '2021']
# ['5', '12', '2021']
# ['19', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['30', '07', '2021']
# ['19', '09', '2021']
# ['29', '11', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['30', '07', '2021']
# ['30', '07', '2021']
# ['12', '11', '2021']
# ['19', '10', '2021']
# ['21', '10', '2021']
# ['21', '10', '2021']
# ['21', '10', '2021']
# ['28', '07', '2021']
# ['30', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['28', '07', '2021']
# ['1', '11', '2021']
# ['20', '09', '2021']
# ['4', '12', '2021']
# ['28', '07', '2021']
# ['2', '08', '2021']
# ['4', '12', '2021']
# ['12', '11', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['22', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['8', '11', '2021']
# ['22', '10', '2021']
# ['4', '12', '2021']
# ['30', '11', '2021']
# ['16', '11', '2021']
# ['4', '12', '2021']
# ['6', '11', '2021']
# ['22', '10', '2021']
# ['4', '12', '2021']
# ['1', '11', '2021']
# ['4', '12', '2021']
# ['27', '07', '2021']
# ['16', '11', '2021']
# ['28', '07', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['22', '10', '2021']
# ['22', '10', '2021']
# ['12', '11', '2021']
# ['1', '11', '2021']
# ['4', '12', '2021']
# ['23', '10', '2021']
# ['5', '11', '2021']
# ['6', '11', '2021']
# ['5', '12', '2021']
# ['21', '10', '2021']
# ['17', '11', '2021']
# ['29', '07', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['21', '10', '2021']
# ['12', '11', '2021']
# ['25', '10', '2021']
# ['1', '11', '2021']
# ['29', '11', '2021']
# ['13', '09', '2021']
# ['23', '10', '2021']
# ['21', '10', '2021']
# ['21', '10', '2021']
# ['20', '10', '2021']
# ['21', '10', '2021']
# ['17', '09', '2021']
# ['13', '09', '2021']
# ['6', '11', '2021']
# ['13', '09', '2021']
# ['28', '07', '2021']
# ['30', '11', '2021']
# ['22', '10', '2021']
# ['30', '11', '2021']
# ['21', '10', '2021']
# ['27', '07', '2021']
# ['2', '08', '2021']
# ['30', '11', '2021']
# ['28', '07', '2021']
# ['5', '12', '2021']
# ['1', '11', '2021']
# ['8', '11', '2021']
# ['5', '12', '2021']
# ['21', '10', '2021']
# ['4', '12', '2021']
# ['5', '11', '2021']
# ['2', '11', '2021']
# ['3', '08', '2021']
# ['14', '11', '2021']
# ['31', '08', '2021']
# ['21', '09', '2021']
# ['3', '08', '2021']
# ['17', '11', '2021']
# ['3', '08', '2021']
# ['3', '08', '2021']
# ['3', '08', '2021']
# ['17', '11', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['28', '11', '2021']
# ['4', '12', '2021']
# ['3', '08', '2021']
# ['14', '11', '2021']
# ['24', '10', '2021']
# ['6', '11', '2021']
# ['30', '11', '2021']
# ['5', '12', '2021']
# ['2', '08', '2021']
# ['15', '11', '2021']
# ['28', '11', '2021']
# ['16', '10', '2021']
# ['16', '10', '2021']
# ['28', '11', '2021']
# ['28', '11', '2021']
# ['21', '09', '2021']
# ['16', '10', '2021']
# ['28', '10', '2021']
# ['16', '10', '2021']
# ['16', '10', '2021']
# ['4', '12', '2021']
# ['11', '07', '2021']
# ['16', '10', '2021']
# ['25', '10', '2021']
# ['21', '09', '2021']
# ['14', '12', '2020']
# ['4', '08', '2021']
# ['7', '09', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['25', '10', '2021']
# ['25', '10', '2021']
# ['4', '12', '2021']
# ['7', '10', '2021']
# ['25', '10', '2021']
# ['5', '12', '2021']
# ['30', '11', '2021']
# ['31', '08', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['14', '10', '2021']
# ['4', '08', '2021']
# ['9', '11', '2021']
# ['8', '09', '2021']
# ['5', '12', '2021']
# ['28', '11', '2021']
# ['3', '08', '2021']
# ['3', '08', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['12', '09', '2021']
# ['12', '09', '2021']
# ['25', '10', '2021']
# ['4', '08', '2021']
# ['2', '11', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['28', '11', '2021']
# ['8', '09', '2021']
# ['1', '11', '2021']
# ['5', '12', '2021']
# ['31', '07', '2021']
# ['31', '07', '2021']
# ['30', '11', '2021']
# ['31', '07', '2021']
# ['17', '09', '2021']
# ['18', '10', '2021']
# ['12', '11', '2021']
# ['29', '11', '2021']
# ['5', '12', '2021']
# ['23', '10', '2021']
# ['4', '09', '2021']
# ['31', '07', '2021']
# ['29', '11', '2021']
# ['6', '11', '2021']
# ['4', '12', '2021']
# ['23', '10', '2021']
# ['18', '10', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['20', '09', '2021']
# ['24', '10', '2021']
# ['30', '11', '2021']
# ['17', '11', '2021']
# ['23', '10', '2021']
# ['12', '11', '2021']
# ['12', '11', '2021']
# ['2', '11', '2021']
# ['5', '12', '2021']
# ['29', '11', '2021']
# ['5', '12', '2021']
# ['6', '11', '2021']
# ['18', '11', '2021']
# ['4', '09', '2021']
# ['12', '11', '2021']
# ['29', '11', '2021']
# ['4', '12', '2021']
# ['18', '10', '2021']
# ['1', '09', '2021']
# ['20', '09', '2021']
# ['23', '10', '2021']
# ['29', '11', '2021']
# ['12', '11', '2021']
# ['5', '12', '2021']
# ['17', '10', '2021']
# ['13', '09', '2021']
# ['31', '08', '2021']
# ['2', '08', '2021']
# ['5', '12', '2021']
# ['2', '08', '2021']
# ['18', '10', '2021']
# ['1', '09', '2021']
# ['17', '09', '2021']
# ['6', '12', '2021']
# ['24', '10', '2021']
# ['2', '08', '2021']
# ['17', '10', '2021']
# ['15', '11', '2021']
# ['12', '11', '2021']
# ['2', '08', '2021']
# ['2', '08', '2021']
# ['18', '10', '2021']
# ['5', '12', '2021']
# ['8', '09', '2021']
# ['17', '10', '2021']
# ['8', '09', '2021']
# ['4', '09', '2021']
# ['4', '12', '2021']
# ['29', '11', '2021']
# ['5', '12', '2021']
# ['18', '11', '2021']
# ['2', '11', '2021']
# ['3', '11', '2021']
# ['2', '12', '2021']
# ['27', '08', '2021']
# ['22', '11', '2021']
# ['3', '12', '2021']
# ['30', '09', '2021']
# ['22', '11', '2021']
# ['22', '11', '2021']
# ['23', '08', '2021']
# ['23', '08', '2021']
# ['15', '09', '2021']
# ['23', '08', '2021']
# ['3', '12', '2021']
# ['27', '09', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['4', '11', '2021']
# ['30', '09', '2021']
# ['30', '09', '2021']
# ['3', '12', '2021']
# ['30', '09', '2021']
# ['4', '11', '2021']
# ['28', '10', '2021']
# ['29', '09', '2021']
# ['6', '09', '2021']
# ['30', '10', '2021']
# ['7', '11', '2021']
# ['28', '10', '2021']
# ['3', '12', '2021']
# ['7', '09', '2021']
# ['22', '11', '2021']
# ['28', '10', '2021']
# ['22', '11', '2021']
# ['9', '11', '2021']
# ['3', '12', '2021']
# ['4', '11', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['23', '08', '2021']
# ['19', '10', '2021']
# ['3', '12', '2021']
# ['20', '11', '2021']
# ['27', '09', '2021']
# ['16', '11', '2021']
# ['23', '08', '2021']
# ['6', '09', '2021']
# ['15', '09', '2021']
# ['23', '08', '2021']
# ['21', '11', '2021']
# ['30', '09', '2021']
# ['7', '11', '2021']
# ['3', '12', '2021']
# ['9', '11', '2021']
# ['21', '11', '2021']
# ['14', '09', '2021']
# ['28', '10', '2021']
# ['1', '10', '2021']
# ['28', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['18', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['22', '11', '2021']
# ['22', '11', '2021']
# ['28', '10', '2021']
# ['8', '11', '2021']
# ['3', '12', '2021']
# ['5', '11', '2021']
# ['6', '12', '2021']
# ['4', '11', '2021']
# ['27', '08', '2021']
# ['28', '10', '2021']
# ['22', '11', '2021']
# ['22', '11', '2021']
# ['1', '10', '2021']
# ['4', '11', '2021']
# ['22', '11', '2021']
# ['3', '12', '2021']
# ['14', '11', '2021']
# ['10', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['3', '12', '2021']
# ['30', '10', '2021']
# ['10', '11', '2021']
# ['28', '10', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['22', '11', '2021']
# ['6', '12', '2021']
# ['2', '10', '2021']
# ['10', '11', '2021']
# ['15', '09', '2021']
# ['1', '10', '2021']
# ['1', '12', '2021']
# ['6', '09', '2021']
# ['27', '08', '2021']
# ['6', '12', '2021']
# ['14', '09', '2021']
# ['1', '10', '2021']
# ['5', '11', '2021']
# ['30', '10', '2021']
# ['14', '11', '2021']
# ['22', '11', '2021']
# ['3', '12', '2021']
# ['30', '09', '2021']
# ['30', '09', '2021']
# ['22', '11', '2021']
# ['3', '12', '2021']
# ['10', '11', '2021']
# ['28', '10', '2021']
# ['30', '09', '2021']
# ['22', '11', '2021']
# ['22', '11', '2021']
# ['21', '08', '2021']
# ['22', '11', '2021']
# ['6', '12', '2021']
# ['20', '08', '2021']
# ['28', '10', '2021']
# ['10', '11', '2021']
# ['16', '11', '2021']
# ['6', '12', '2021']
# ['1', '10', '2021']
# ['28', '10', '2021']
# ['6', '12', '2021']
# ['1', '10', '2021']
# ['28', '10', '2021']
# ['1', '12', '2021']
# ['1', '10', '2021']
# ['10', '09', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['6', '12', '2021']
# ['16', '11', '2021']
# ['15', '11', '2021']
# ['25', '08', '2021']
# ['9', '11', '2021']
# ['28', '10', '2021']
# ['19', '11', '2021']
# ['25', '11', '2021']
# ['28', '09', '2021']
# ['28', '09', '2021']
# ['28', '09', '2021']
# ['5', '11', '2021']
# ['27', '10', '2021']
# ['15', '11', '2021']
# ['19', '11', '2021']
# ['26', '08', '2021']
# ['14', '11', '2021']
# ['27', '10', '2021']
# ['19', '11', '2021']
# ['25', '08', '2021']
# ['15', '11', '2021']
# ['14', '09', '2021']
# ['7', '09', '2021']
# ['22', '11', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['19', '11', '2021']
# ['15', '09', '2021']
# ['16', '11', '2021']
# ['2', '12', '2021']
# ['14', '09', '2021']
# ['16', '11', '2021']
# ['2', '12', '2021']
# ['29', '10', '2021']
# ['14', '09', '2021']
# ['25', '08', '2021']
# ['5', '11', '2021']
# ['27', '10', '2021']
# ['9', '11', '2021']
# ['8', '11', '2021']
# ['28', '09', '2021']
# ['18', '11', '2021']
# ['2', '12', '2021']
# ['29', '10', '2021']
# ['19', '11', '2021']
# ['25', '08', '2021']
# ['2', '12', '2021']
# ['28', '09', '2021']
# ['28', '09', '2021']
# ['2', '12', '2021']
# ['16', '03', '2021']
# ['25', '08', '2021']
# ['15', '11', '2021']
# ['29', '10', '2021']
# ['28', '09', '2021']
# ['2', '11', '2021']
# ['5', '11', '2021']
# ['19', '11', '2021']
# ['24', '08', '2021']
# ['30', '10', '2021']
# ['4', '11', '2021']
# ['18', '11', '2021']
# ['20', '11', '2021']
# ['2', '12', '2021']
# ['24', '08', '2021']
# ['2', '12', '2021']
# ['20', '11', '2021']
# ['20', '11', '2021']
# ['29', '09', '2021']
# ['29', '09', '2021']
# ['20', '11', '2021']
# ['24', '08', '2021']
# ['29', '09', '2021']
# ['30', '10', '2021']
# ['6', '09', '2021']
# ['2', '12', '2021']
# ['24', '08', '2021']
# ['23', '08', '2021']
# ['9', '11', '2021']
# ['19', '10', '2021']
# ['4', '10', '2021']
# ['29', '10', '2021']
# ['24', '08', '2021']
# ['2', '12', '2021']
# ['29', '10', '2021']
# ['27', '09', '2021']
# ['4', '11', '2021']
# ['29', '09', '2021']
# ['2', '12', '2021']
# ['14', '09', '2021']
# ['25', '10', '2021']
# ['24', '08', '2021']
# ['24', '08', '2021']
# ['29', '10', '2021']
# ['2', '12', '2021']
# ['29', '09', '2021']
# ['24', '08', '2021']
# ['19', '11', '2021']
# ['19', '11', '2021']
# ['29', '10', '2021']
# ['7', '09', '2021']
# ['20', '10', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['24', '08', '2021']
# ['20', '11', '2021']
# ['15', '11', '2021']
# ['24', '08', '2021']
# ['24', '08', '2021']
# ['26', '08', '2021']
# ['2', '12', '2021']
# ['29', '09', '2021']
# ['5', '11', '2021']
# ['24', '08', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['3', '10', '2021']
# ['1', '10', '2021']
# ['4', '12', '2021']
# ['16', '11', '2021']
# ['4', '11', '2021']
# ['5', '11', '2021']
# ['5', '10', '2021']
# ['6', '12', '2021']
# ['10', '11', '2021']
# ['17', '08', '2021']
# ['5', '10', '2021']
# ['5', '10', '2021']
# ['10', '11', '2021']
# ['17', '08', '2021']
# ['24', '11', '2021']
# ['17', '08', '2021']
# ['31', '10', '2021']
# ['24', '11', '2021']
# ['6', '12', '2021']
# ['17', '08', '2021']
# ['10', '11', '2021']
# ['17', '08', '2021']
# ['27', '09', '2021']
# ['1', '06', '2021']
# ['24', '11', '2021']
# ['1', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['27', '10', '2021']
# ['17', '08', '2021']
# ['17', '08', '2021']
# ['5', '10', '2021']
# ['6', '12', '2021']
# ['24', '11', '2021']
# ['3', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['23', '11', '2021']
# ['23', '11', '2021']
# ['25', '09', '2021']
# ['7', '10', '2021']
# ['10', '11', '2021']
# ['10', '09', '2021']
# ['1', '12', '2021']
# ['28', '08', '2021']
# ['5', '10', '2021']
# ['7', '10', '2021']
# ['5', '10', '2021']
# ['7', '10', '2021']
# ['30', '08', '2021']
# ['10', '09', '2021']
# ['8', '11', '2021']
# ['1', '12', '2021']
# ['24', '11', '2021']
# ['17', '08', '2021']
# ['19', '08', '2021']
# ['8', '11', '2021']
# ['5', '10', '2021']
# ['17', '08', '2021']
# ['17', '08', '2021']
# ['17', '08', '2021']
# ['6', '12', '2021']
# ['17', '08', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['17', '08', '2021']
# ['10', '11', '2021']
# ['6', '10', '2021']
# ['7', '10', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['24', '11', '2021']
# ['10', '09', '2021']
# ['29', '08', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['23', '08', '2021']
# ['27', '10', '2021']
# ['16', '09', '2021']
# ['4', '12', '2021']
# ['24', '11', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['24', '11', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['27', '10', '2021']
# ['27', '10', '2021']
# ['27', '10', '2021']
# ['16', '08', '2021']
# ['6', '12', '2021']
# ['16', '08', '2021']
# ['6', '10', '2021']
# ['6', '10', '2021']
# ['6', '10', '2021']
# ['24', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['16', '08', '2021']
# ['4', '11', '2021']
# ['24', '11', '2021']
# ['24', '09', '2021']
# ['6', '10', '2021']
# ['24', '11', '2021']
# ['17', '08', '2021']
# ['4', '11', '2021']
# ['6', '10', '2021']
# ['4', '12', '2021']
# ['24', '11', '2021']
# ['6', '10', '2021']
# ['24', '11', '2021']
# ['10', '08', '2021']
# ['4', '12', '2021']
# ['6', '10', '2021']
# ['16', '08', '2021']
# ['24', '11', '2021']
# ['10', '11', '2021']
# ['4', '12', '2021']
# ['24', '11', '2021']
# ['24', '11', '2021']
# ['18', '11', '2021']
# ['27', '10', '2021']
# ['25', '09', '2021']
# ['4', '12', '2021']
# ['8', '09', '2021']
# ['3', '12', '2021']
# ['24', '11', '2021']
# ['31', '10', '2021']
# ['6', '12', '2021']
# ['4', '11', '2021']
# ['6', '10', '2021']
# ['24', '11', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['24', '11', '2021']
# ['27', '10', '2021']
# ['1', '12', '2021']
# ['3', '12', '2021']
# ['25', '09', '2021']
# ['6', '09', '2021']
# ['6', '12', '2021']
# ['18', '08', '2021']
# ['24', '09', '2021']
# ['4', '10', '2021']
# ['25', '09', '2021']
# ['19', '08', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['26', '10', '2021']
# ['28', '08', '2021']
# ['4', '10', '2021']
# ['17', '11', '2021']
# ['10', '09', '2021']
# ['25', '09', '2021']
# ['16', '09', '2021']
# ['14', '08', '2021']
# ['25', '09', '2021']
# ['6', '12', '2021']
# ['24', '11', '2021']
# ['23', '11', '2021']
# ['4', '12', '2021']
# ['23', '11', '2021']
# ['30', '08', '2021']
# ['4', '11', '2021']
# ['4', '10', '2021']
# ['6', '12', '2021']
# ['3', '12', '2021']
# ['13', '08', '2021']
# ['6', '12', '2021']
# ['5', '11', '2021']
# ['18', '08', '2021']
# ['19', '08', '2021']
# ['4', '10', '2021']
# ['14', '09', '2021']
# ['23', '11', '2021']
# ['23', '11', '2021']
# ['7', '10', '2021']
# ['3', '12', '2021']
# ['26', '09', '2021']
# ['1', '12', '2021']
# ['27', '10', '2021']
# ['6', '12', '2021']
# ['28', '10', '2021']
# ['6', '12', '2021']
# ['3', '12', '2021']
# ['19', '08', '2021']
# ['4', '12', '2021']
# ['25', '11', '2021']
# ['4', '11', '2021']
# ['27', '10', '2021']
# ['4', '10', '2021']
# ['4', '10', '2021']
# ['23', '11', '2021']
# ['4', '10', '2021']
# ['6', '12', '2021']
# ['23', '11', '2021']
# ['3', '12', '2021']
# ['7', '10', '2021']
# ['6', '12', '2021']
# ['28', '08', '2021']
# ['7', '11', '2021']
# ['7', '10', '2021']
# ['13', '11', '2021']
# ['11', '11', '2021']
# ['3', '12', '2021']
# ['6', '12', '2021']
# ['17', '08', '2021']
# ['25', '09', '2021']
# ['4', '10', '2021']
# ['13', '11', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['23', '11', '2021']
# ['6', '09', '2021']
# ['4', '10', '2021']
# ['6', '12', '2021']
# ['3', '12', '2021']
# ['23', '11', '2021']
# ['11', '09', '2021']
# ['23', '11', '2021']
# ['30', '11', '2021']
# ['24', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['23', '11', '2021']
# ['6', '12', '2021']
# ['23', '11', '2021']
# ['5', '10', '2021']
# ['31', '10', '2021']
# ['23', '11', '2021']
# ['30', '08', '2021']
# ['6', '12', '2021']
# ['1', '12', '2021']
# ['3', '12', '2021']
# ['4', '10', '2021']
# ['6', '12', '2021']
# ['18', '08', '2021']
# ['6', '12', '2021']
# ['10', '11', '2021']
# ['4', '11', '2021']
# ['4', '10', '2021']
# ['9', '09', '2021']
# ['3', '12', '2021']
# ['27', '11', '2021']
# ['27', '09', '2021']
# ['7', '05', '2020']
# ['14', '10', '2021']
# ['25', '11', '2021']
# ['6', '12', '2021']
# ['1', '04', '2021']
# ['6', '12', '2021']
# ['15', '11', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['22', '11', '2021']
# ['6', '12', '2021']
# ['12', '11', '2021']
# ['3', '09', '2021']
# ['4', '12', '2021']
# ['17', '09', '2021']
# ['26', '10', '2021']
# ['27', '07', '2021']
# ['26', '10', '2021']
# ['22', '10', '2021']
# ['26', '10', '2021']
# ['2', '12', '2021']
# ['27', '07', '2021']
# ['4', '12', '2021']
# ['30', '10', '2021']
# ['29', '10', '2021']
# ['4', '12', '2021']
# ['22', '10', '2021']
# ['27', '07', '2021']
# ['22', '10', '2021']
# ['15', '11', '2021']
# ['4', '12', '2021']
# ['17', '09', '2021']
# ['27', '07', '2021']
# ['29', '10', '2021']
# ['22', '10', '2021']
# ['26', '10', '2021']
# ['16', '09', '2021']
# ['27', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['2', '12', '2021']
# ['4', '09', '2021']
# ['29', '10', '2021']
# ['22', '10', '2021']
# ['4', '12', '2021']
# ['29', '10', '2021']
# ['26', '10', '2021']
# ['26', '10', '2021']
# ['4', '12', '2021']
# ['8', '11', '2021']
# ['14', '09', '2021']
# ['18', '11', '2021']
# ['2', '12', '2021']
# ['6', '09', '2021']
# ['13', '11', '2021']
# ['2', '12', '2021']
# ['27', '10', '2021']
# ['22', '10', '2021']
# ...
# ['9', '11', '2021']
# ['1', '12', '2021']
# ['11', '05', '2021']
# ['11', '05', '2021']
# ['10', '05', '2021']
# ['16', '06', '2021']
# ['24', '11', '2021']
# ['27', '11', '2021']
# ['16', '06', '2021']
# ['16', '06', '2021']
# ['17', '05', '2021']
# ['1', '11', '2021']
# ['16', '05', '2021']
# ['19', '11', '2021']
# ['27', '11', '2021']
# ['16', '06', '2021']
# ['16', '06', '2021']
# ['22', '03', '2021']
# ['9', '11', '2021']
# ['13', '11', '2021']
# ['12', '06', '2021']
# ['4', '12', '2021']
# ['12', '07', '2021']
# ['3', '09', '2021']
# ['16', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['16', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['18', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['17', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['31', '08', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['31', '08', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['31', '08', '2021']
# ['5', '12', '2021']
# ['31', '08', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['8', '09', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['13', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['14', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['14', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['15', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['19', '08', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['21', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['21', '08', '2021']
# ['5', '12', '2021']
# ['21', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['16', '08', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['23', '10', '2021']
# ['4', '12', '2021']
# ['17', '08', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['27', '08', '2021']
# ['5', '12', '2021']
# ['19', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['23', '08', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['20', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['6', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['7', '10', '2021']
# ['23', '09', '2021']
# ['6', '12', '2021']
# ['25', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['2', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['1', '10', '2021']
# ['6', '12', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['2', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['29', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['29', '09', '2021']
# ['6', '12', '2021']
# ['29', '09', '2021']
# ['6', '12', '2021']
# ['29', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['4', '10', '2021']
# ['4', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['29', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['4', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['12', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['11', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['15', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['12', '10', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['5', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['20', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['8', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['7', '10', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['22', '09', '2021']
# ['23', '09', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['6', '12', '2021']
# ['18', '09', '2021']
# ['6', '12', '2021']
# ['9', '10', '2021']
# ['4', '12', '2021']
# ['5', '12', '2021']
# ['8', '11', '2021']
# ['6', '08', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['29', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['26', '10', '2021']
# ['4', '12', '2021']
# ['26', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['12', '08', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['4', '12', '2021']
# ['3', '12', '2021']
# ['2', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['26', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['3', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['25', '10', '2021']
# ['2', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['25', '10', '2021']
# ['2', '12', '2021']
# ['3', '12', '2021']
# ['25', '10', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['4', '12', '2021']
# ['2', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['28', '10', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['1', '08', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['28', '10', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']
# ['3', '12', '2021']

# %% [markdown]
# ## Note: year only contain "2021"

# %%
unique_list = []

for x in year:
    if x in unique_list:
        continue
    else:
        unique_list.append(x)

# %%
dataset['month'] = month

# %%
dataset = dataset.drop(["createdAt"], axis = 1)

# %%
dataset.to_csv("pre_aggregatedata.csv", index=False)
