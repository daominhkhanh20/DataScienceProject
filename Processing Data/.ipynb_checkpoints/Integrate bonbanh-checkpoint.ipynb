# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_json('../Data/bonbanh.json')
data
# Out:
#                                                      url  \
# 0      https://bonbanh.com/xe-kia-carens-sxat-2012-40...
# 1      https://bonbanh.com/xe-ford-ranger-xls-2.2l-4x...
# 2       https://bonbanh.com/xe-lexus-lx-570-2008-4013759
# 3      https://bonbanh.com/xe-thaco-ollin-250-2014-40...
# 4      https://bonbanh.com/xe-mercedes_benz-e_class-e...
# ...                                                  ...
# 39298  https://bonbanh.com/xe-mercedes_benz-c_class-c...
# 39299  https://bonbanh.com/xe-vinfast-fadil-1.4-at-pl...
# 39300  https://bonbanh.com/xe-chevrolet-lacetti-1.6-2...
# 39301  https://bonbanh.com/xe-mitsubishi-xpander-cros...
# 39302  https://bonbanh.com/xe-vinfast-fadil-1.4-at-20...
#
#                                                    title  \
# 0                Xe\tKia Carens\tSXAT\t2012\t- 310 Triệu
# 1      Xe\tFord Ranger\tXLS 2.2L 4x2 MT\t2021\t- 630 ...
# 2              Xe\tLexus LX\t570\t2008\t- 2 Tỷ 450 Triệu
# 3                Xe\tThaco Ollin\t250\t2014\t- 240 Triệu
# 4      Xe\tMercedes Benz E class\tE200\t2014\t- 850 T...
# ...                                                  ...
# 39298  Xe\tMercedes Benz C class\tC250 Exclusive\t201...
# 39299  Xe\tVinFast Fadil\t1.4 AT Plus\t2021\t- 388 Triệu
# 39300      Xe\tChevrolet Lacetti\t1.6\t2011\t- 195 Triệu
# 39301  Xe\tMitsubishi Xpander\tCross 1.5 AT\t2020\t- ...
# 39302       Xe\tVinFast Fadil\t1.4 AT\t2021\t- 369 Triệu
#
#                                              description  \
# 0      [Siêu thị ô tô Bình Dương chào bán!,  Kia Care...
# 1      [Ford Ranger XLS 2.2L 4x2 MT 2021, Trang bị hệ...
# 2      [Lexus LX570 5.7L model 2009 đklđ 2011 độ lên ...
# 3      [Thaco ollin 2t3 vừa về. Anh chị em cần sử dụn...
# 4      [Mercedes-benz E200 facelift ,  Sản xuất 2014,...
# ...                                                  ...
# 39298  [Mercedes C250 Exclusive,  Sản xuất 2016. Đăng...
# 39299  [Chương trình áp dụng, Giảm 10% giá niêm yết, ...
# 39300  [Bán Chervorlet Lacetti màu vàng, đời 2011 số ...
# 39301  [Giá nhập khẩu có chất lượng cao nhưng giá bán...
# 39302  [Bán VinFast Fadil 1.4 AT màu đỏ cam mới 100% ...
#
#                             seller  \
# 0         Siêu thị ô tô Bình Dương
# 1                     Mỹ Đình Ford
# 2                 Sàn ôtô Việt Nam
# 3                      Ô Tô Anh Ty
# 4                   LT Luxury Auto
# ...                            ...
# 39298                        Vauto
# 39299           Vinfast Royal City
# 39300                         None
# 39301  Mitsubishi An Dân Vĩnh Phúc
# 39302               Ô tô Minh Hưng
#
#                                           seller_address              origin  \
# 0      Địa chỉ: Ngã ba Ông Xã, ĐT743B, khu phố Đông T...  Lắp ráp trong nước
# 1      Địa chỉ: đường Trịnh Văn Bô, P. Xuân Phương, Q...           Nhập khẩu
# 2             Địa chỉ: 25 Lê Văn Lương, Cầu Giấy Hà Nội            Nhập khẩu
# 3      Địa chỉ: 2094 Ql1A, P. Tân Chánh Hiệp, Q.12 TP...  Lắp ráp trong nước
# 4      Địa chỉ: 123-125 Phạm Văn Đồng, Quận Bắc Từ Li...  Lắp ráp trong nước
# ...                                                  ...                 ...
# 39298      Địa chỉ: 524 Nguyễn Văn Cừ, Long Biên Hà Nội   Lắp ráp trong nước
# 39299       Địa chỉ: 72A Nguyễn Trãi, Thanh Xuân Hà Nội   Lắp ráp trong nước
# 39300                                              Hoặc   Lắp ráp trong nước
# 39301  Địa chỉ: 628 Đường Mê Linh, P. Khai Quang, Tp ...           Nhập khẩu
# 39302  Địa chỉ: Lô7 - Kcn Lai Xá - Kim Chung - Hoài Đ...  Lắp ráp trong nước
#
#            status           car_model  km_number exterior_color  \
# 0      Xe đã dùng           Crossover  60,000 Km           Xanh
# 1          Xe mới  Bán tải / Pickup       0 Km           Xanh
# 2      Xe đã dùng                 SUV       0 Km          Trắng
# 3      Xe đã dùng               Truck       0 Km           Xanh
# 4      Xe đã dùng               Sedan       0 Km          Trắng
# ...           ...                 ...        ...            ...
# 39298  Xe đã dùng               Sedan  37,000 Km            Đen
# 39299      Xe mới           Hatchback       0 Km           Xanh
# 39300  Xe đã dùng               Sedan       0 Km           Vàng
# 39301      Xe mới                 SUV       0 Km            Cam
# 39302      Xe mới           Hatchback       0 Km             Đỏ
#
#       interior_color number_door number_seat       engine   refueling_system  \
# 0                  -       5 cửa       7 chỗ  Xăng\t2.0 L               None
# 1                  -       4 cửa       5 chỗ   Dầu\t2.2 L               None
# 2                Kem       5 cửa       7 chỗ  Xăng\t5.7 L               None
# 3                Xám       2 cửa       3 chỗ          Dầu               None
# 4                  -       4 cửa       5 chỗ  Xăng\t2.0 L               None
# ...              ...         ...         ...          ...                ...
# 39298            Đen       4 cửa       5 chỗ  Xăng\t2.0 L               None
# 39299            Đen       5 cửa       5 chỗ  Xăng\t1.4 L               None
# 39300            Ghi       4 cửa       5 chỗ  Xăng\t1.6 L               None
# 39301            Đen       5 cửa       7 chỗ  Xăng\t1.5 L  Phun xăng điện tử
# 39302       Màu khác       5 cửa       5 chỗ  Xăng\t1.4 L  Phun xăng điện tử
#
#              gear                     actuator fuel_comsumption
# 0      Số tự động     FWD - Dẫn động cầu trước          L/100Km
# 1          Số tay       RFD - Dẫn động cầu sau          L/100Km
# 2      Số tự động  AWD - 4 bánh toàn thời gian          L/100Km
# 3          Số tay       RFD - Dẫn động cầu sau          L/100Km
# 4      Số tự động       RFD - Dẫn động cầu sau          L/100Km
# ...           ...                          ...              ...
# 39298  Số tự động       RFD - Dẫn động cầu sau          L/100Km
# 39299  Số tự động     FWD - Dẫn động cầu trước          L/100Km
# 39300      Số tay     FWD - Dẫn động cầu trước          L/100Km
# 39301  Số tự động     FWD - Dẫn động cầu trước       7\tL/100Km
# 39302  Số tự động     FWD - Dẫn động cầu trước       6\tL/100Km
#
# [39303 rows x 18 columns]

# %%
# data = data[['title','description','url']]

# %%
data1 = pd.read_csv('../Data/data_bonbanh.csv')

# %%
res = data.join(data1, lsuffix='_caller', rsuffix='_other')

# %%
colsDrop = ['id.1','car_model_id','id.2','source_id']

# %%
res = res.drop(columns=colsDrop)

# %%
res.to_csv('../Data/bonbanh.csv')
