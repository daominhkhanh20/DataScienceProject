# %%
import pandas as pd

# %%
data =  pd.read_csv('./CrawlData/chotot_api.csv')
# Out:
# /home/vukhanh/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (55,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
tmp = pd.read_csv('./Data/AggregateData.csv')

# %%
ls = tmp[tmp['website']=='chotot']

# %%
ls
# Out:
#                                                      url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      https://xe.chotot.com/mua-ban-oto-thanh-pho-lo...
# 4      https://xe.chotot.com/mua-ban-oto-quan-tan-bin...
# ...                                                  ...
# 30355                                                NaN
# 30356                                                NaN
# 30357                                                NaN
# 30358                                                NaN
# 30359                                                NaN
#
#                                              description    origin  \
# 0      🔹 HÀNG MỚI VỀ\n🔹 BMW 520i \n🔹 MODEL 2016\n🔹 Od...       Đức
# 1      Bán nissan - Gran Livina nhập khẩu số tự động ...  Nhật Bản
# 2      Auto88 về Mercedes C200 sx 2017 đky 2/2018 chạ...  Việt Nam
# ...
